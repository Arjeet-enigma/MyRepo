# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebbok, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Java

# %% [markdown]
# Some of the commonly used libraries used by Data Scientist include:
# 1. Pandas
# 2. Numpy
# 3. Scipy
# 4. Matplotlib
# 5. Keras

# %% [markdown]
# | Data Science Tools |
# | :---: |
# | MySQL |
# | KubeFlow |
# | Pixie Dust |
# | Tensorflow |
# | Git Hub|

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expression in Python

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by diving by 60
minutes = 200
hours = 200//60
print(hours)
# Out:
# 3

# %% [markdown]
# **Objective**
# * Determining the language to learn based on its citeria
# * Benefits of Python
# * R language Users
# * SQL elements & its benefits
# * Learning new languages such as Java, Scala, C++, Javascript, Julia

# %% [markdown]
# ## Author
#  Arjeet
